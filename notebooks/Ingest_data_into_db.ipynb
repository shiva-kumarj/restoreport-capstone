# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
df = pd.read_csv('delete/business.csv', encoding='utf-8')

# %%
assert not df.isnull().any().any(), "AssertionError: Null values found in the final cleaned dataframe."

# %%
df.isnull().sum()
# Out:
# business_id                                0
# name                                       0
# address                                  291
# city                                       0
# state                                      0
# postal_code                                0
# latitude                                   0
# longitude                                  0
# stars                                      0
# review_count                               0
# Monday                                     0
# Tuesday                                    0
# Wednesday                                  0
# Thursday                                   0
# Friday                                     0
# Saturday                                   0
# Sunday                                     0
# attributes.OutdoorSeating                  0
# attributes.RestaurantsReservations         0
# attributes.Alcohol                         0
# attributes.RestaurantsDelivery             0
# ...

# %%
df_iter = pd.read_csv('cleaned_dataset/business.csv', iterator=True, chunksize=1000)

# %%
df = next(df_iter)

# %%
engine = create_engine('postgresql://root:root@localhost:5432/yelp_db')

# %%
engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\blahb\anaconda3\envs\capstone_env\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\blahb\anaconda3\envs\capstone_env\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File c:\Users\blahb\anaconda3\envs\capstone_env\Lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
# ...

# %%
import psycopg2

host = 'localhost'
db = 'yelp_db'
user = 'root'
password = 'root'

conn = psycopg2.connect(host=f'{host}', database=f'{db}', user=f'{user}', password=f'{password}')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[13], line 8
#       5 user = 'root'
#       6 password = 'root'
# ----> 8 conn = psycopg2.connect(host=f'{host}', database=f'{db}', user=f'{user}', password=f'{password}')
#
# File c:\Users\blahb\anaconda3\envs\capstone_env\Lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: FATAL:  database "yelp_db" does not exist

# %%
df.head(n=0).to_sql(name='business_data', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\blahb\anaconda3\envs\capstone_env\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\blahb\anaconda3\envs\capstone_env\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File c:\Users\blahb\anaconda3\envs\capstone_env\Lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
# ...

# %%
from time import time

# %%
while True:
    t_start = time()
    df = next(df_iter)
    df.to_sql(name='business_data', con=engine, if_exists='append')
    t_end = time()
    print(f'Added another chunk.. took %.3f seconds {(t_end-t_start)}')
# Out:
# Added another chunk.. took %.3f seconds 0.27346301078796387
# Added another chunk.. took %.3f seconds 0.2337799072265625
# Added another chunk.. took %.3f seconds 0.22852039337158203
# Added another chunk.. took %.3f seconds 0.20635032653808594
# Added another chunk.. took %.3f seconds 0.28246593475341797
# Added another chunk.. took %.3f seconds 0.21747708320617676
# Added another chunk.. took %.3f seconds 0.19915771484375
# Added another chunk.. took %.3f seconds 0.23000764846801758
# Added another chunk.. took %.3f seconds 0.20998692512512207
# Added another chunk.. took %.3f seconds 0.24056482315063477
# Added another chunk.. took %.3f seconds 0.27925944328308105
# Added another chunk.. took %.3f seconds 0.15224719047546387
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[7], line 3
#       1 while True:
#       2     t_start = time()
# ...
